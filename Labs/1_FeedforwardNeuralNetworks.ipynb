# %% [markdown]
# # Artificial Neural Networks and Deep Learning
#
# ---
#
# ## Lecture 1: Feedforward Neural Networks

# %% [markdown]
# ### 🌐 Connect Colab to Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Polimi/S3/ANNDL

# %% [markdown]
# ### ⚙️ Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.0

# %% [markdown]
# ### ⏳ Load Data

# %%
# Load the Iris dataset into a variable called 'data'
data = load_iris()

# Print the description of the Iris dataset
print(data.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# :Missing Attribute Values: None
# :Class Distribution: 33.3% for each of 3 classes.
# :Creator: R.A. Fisher
# :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
# :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. dropdown:: References
#
#   - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#     Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#     Mathematical Statistics" (John Wiley, NY, 1950).
#   - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#     (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#   - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#     Structure and Classification Rule for Recognition in Partially Exposed
#     Environments".  IEEE Transactions on Pattern Analysis and Machine
#     Intelligence, Vol. PAMI-2, No. 1, 67-71.
#   - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#     on Information Theory, May 1972, 431-433.
#   - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#     conceptual clustering system finds 3 classes in the data.
#   - Many, many more ...

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*f6KbPXwksAliMIsibFyGJw.png" width="800">

# %% [markdown]
# ### 🔎 Inspect Data

# %%
# Create a DataFrame 'iris_dataset' from the Iris dataset
iris_dataset = pd.DataFrame(data.data, columns=data.feature_names)
print('Iris dataset shape', iris_dataset.shape)

# Display the first 10 rows of the Iris dataset
iris_dataset.head(10)
# Out:
# Iris dataset shape (150, 4)
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1

# %%
# Print the shape of the Iris dataset
print('Iris dataset shape', iris_dataset.shape)

# Generate summary statistics for the Iris dataset
iris_dataset.describe()
# Out:
# Iris dataset shape (150, 4)
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Get the target values from the Iris dataset
target = data.target
print('Target shape', target.shape)

# Calculate the unique target labels and their counts
unique, count = np.unique(target, return_counts=True)
print('Target labels:', unique)
for u in unique:
    print(f'Class {unique[u]} has {count[u]} samples')
# Out:
# Target shape (150,)
# Target labels: [0 1 2]
# Class 0 has 50 samples
# Class 1 has 50 samples
# Class 2 has 50 samples

# %%
# Copy the iris dataset
plot_dataset = iris_dataset.copy()

# Assign target labels to the dataset
plot_dataset["Species"] = target

# Plot using seaborn pairplot
sns.pairplot(plot_dataset, hue="Species", palette="tab10", markers=["o", "s", "D"])
plt.show()

# Clean up by deleting the temporary dataset
del plot_dataset

# %% [markdown]
# #### Split in train, validation and test

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    iris_dataset,
    target,
    test_size=20,
    random_state=seed,
    stratify=target
)

# Further split the combined training and validation set into a training set and a validation set
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val,
    y_train_val,
    test_size=20,
    random_state=seed,
    stratify=y_train_val
)

# Print the shapes of the resulting sets
print('Training set shape:\t', X_train.shape, y_train.shape)
print('Validation set shape:\t', X_val.shape, y_val.shape)
print('Test set shape:\t\t', X_test.shape, y_test.shape)
# Out:
# Training set shape:	 (110, 4) (110,)
# Validation set shape:	 (20, 4) (20,)
# Test set shape:		 (20, 4) (20,)

# %% [markdown]
# ### 🔄 Process Data

# %%
# Compute maximum values for each feature
max_df = X_train.max()

# Display maximum values
print('Iris dataset maximum values')
print(max_df)

# Compute minimum values for each feature
min_df = X_train.min()

# Display minimum values
print('\nIris dataset minimum values')
print(min_df)
# Out:
# Iris dataset maximum values
# sepal length (cm)    7.7
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# dtype: float64
#
# Iris dataset minimum values
# sepal length (cm)    4.3
# sepal width (cm)     2.0
# petal length (cm)    1.0
# petal width (cm)     0.1
# dtype: float64

# %%
# Normalise training data
X_train = (X_train - min_df) / (max_df - min_df)

# Normalise validation data
X_val = (X_val - min_df) / (max_df - min_df)

# Normalise test data
X_test = (X_test - min_df) / (max_df - min_df)

# %%
# Display summary statistics of the normalised training data
X_train.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         110.000000        110.000000         110.000000
# mean            0.457487          0.442045           0.468875
# std             0.244996          0.183070           0.300684
# min             0.000000          0.000000           0.000000
# 25%             0.235294          0.333333           0.101695
# 50%             0.441176          0.416667           0.567797
# 75%             0.617647          0.541667           0.694915
# max             1.000000          1.000000           1.000000
#
#        petal width (cm)
# count        110.000000
# mean           0.461364
# std            0.317410
# min            0.000000
# 25%            0.093750
# 50%            0.500000
# 75%            0.708333
# max            1.000000

# %%
# Apply one-hot encoding to training labels
y_train = tfk.utils.to_categorical(y_train, num_classes=len(unique))

# Apply one-hot encoding to validation labels
y_val = tfk.utils.to_categorical(y_val, num_classes=len(unique))

# Apply one-hot encoding to test labels
y_test = tfk.utils.to_categorical(y_test, num_classes=len(unique))

# Display shapes of the encoded label sets
print('Training set target shape:\t', y_train.shape)
print('Validation set target shape:\t', y_val.shape)
print('Test set target shape:\t\t', y_test.shape)
# Out:
# Training set target shape:	 (110, 3)
# Validation set target shape:	 (20, 3)
# Test set target shape:		 (20, 3)

# %%
# Determine the input shape, corresponding to the number of features
input_shape = X_train.shape[1:]
print(f'Input shape of the network {input_shape}')

# Determine the output shape, corresponding to the number of classes
output_shape = y_train.shape[1]
print(f'Output shape of the network {output_shape}')
# Out:
# Input shape of the network (4,)
# Output shape of the network 3

# %% [markdown]
# ### 🧮 Define Network Parameters

# %%
# Batch size: number of samples processed in each training iteration
batch_size = 16

# Number of epochs: times the entire dataset is passed through the network during training
epochs = 500

# Learning rate: step size for updating the model's weights
learning_rate = 0.001

# %% [markdown]
# ### 🛠️ Build the Model

# %%
def build_model(
    input_shape=input_shape,
    output_shape=output_shape,
    learning_rate=learning_rate,
    seed=seed
):

    # Fix randomness
    tf.random.set_seed(seed)

    # Build the neural network layer by layer
    inputs = tfkl.Input(shape=input_shape, name='Input')

    # Add hidden layer with ReLU activation
    x = tfkl.Dense(units=16, name='Hidden')(inputs)
    x = tfkl.Activation('relu', name='HiddenActivation')(x)

    # Add output layer with softmax activation
    x = tfkl.Dense(units=output_shape, name='Output')(x)
    outputs = tfkl.Activation('softmax', name='Softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=inputs, outputs=outputs, name='FeedforwardNeuralNetwork')

    # Compile the model with loss, optimizer, and metrics
    loss = tfk.losses.CategoricalCrossentropy()
    optimizer = tfk.optimizers.Adam(learning_rate)
    metrics = ['accuracy']
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

    # Return the model
    return model

# %%
# Build the model with specified input and output shapes
model = build_model()

# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "FeedforwardNeuralNetwork"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 4)                    │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Hidden (Dense)                      │ (None, 16)                   │            80 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ HiddenActivation (Activation)       │ (None, 16)                   │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Output (Dense)                      │ (None, 3)                    │            51 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Softmax (Activation)                │ (None, 3)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 131 (524.00 B)
#  Trainable params: 131 (524.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 🧠 Train the Model

# %%
# Train the model and store the training history
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val)
).history

# Calculate the final validation accuracy
final_val_accuracy = round(history['val_accuracy'][-1] * 100, 2)

# Save the trained model to a file with the accuracy included in the filename
model_filename = f'Iris_Feedforward_{final_val_accuracy}.keras'
model.save(model_filename)

# Delete the model to free up memory resources
del model
# Out:
# Epoch 1/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3153 - loss: 1.0700 - val_accuracy: 0.3000 - val_loss: 1.0597
# Epoch 2/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3153 - loss: 1.0568 - val_accuracy: 0.3000 - val_loss: 1.0470
# Epoch 3/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3474 - loss: 1.0441 - val_accuracy: 0.3500 - val_loss: 1.0342
# Epoch 4/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3648 - loss: 1.0311 - val_accuracy: 0.4500 - val_loss: 1.0215
# Epoch 5/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5111 - loss: 1.0176 - val_accuracy: 0.6000 - val_loss: 1.0077
# Epoch 6/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6289 - loss: 1.0028 - val_accuracy: 0.6500 - val_loss: 0.9932
# Epoch 7/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6522 - loss: 0.9871 - val_accuracy: 0.6500 - val_loss: 0.9785
# Epoch 8/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6522 - loss: 0.9713 - val_accuracy: 0.6500 - val_loss: 0.9646
# Epoch 9/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6522 - loss: 0.9557 - val_accuracy: 0.6500 - val_loss: 0.9512
# Epoch 10/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6522 - loss: 0.9411 - val_accuracy: 0.6500 - val_loss: 0.9376
# Epoch 11/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6522 - loss: 0.9272 - val_accuracy: 0.6500 - val_loss: 0.9239
# Epoch 12/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6522 - loss: 0.9136 - val_accuracy: 0.6500 - val_loss: 0.9103
# Epoch 13/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6522 - loss: 0.9003 - val_accuracy: 0.6500 - val_loss: 0.8969
# Epoch 14/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6522 - loss: 0.8871 - val_accuracy: 0.6500 - val_loss: 0.8836
# Epoch 15/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6522 - loss: 0.8740 - val_accuracy: 0.6500 - val_loss: 0.8707
# Epoch 16/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6522 - loss: 0.8613 - val_accuracy: 0.6500 - val_loss: 0.8581
# Epoch 17/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6522 - loss: 0.8492 - val_accuracy: 0.6500 - val_loss: 0.8463
# Epoch 18/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6522 - loss: 0.8377 - val_accuracy: 0.6500 - val_loss: 0.8348
# Epoch 19/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6522 - loss: 0.8265 - val_accuracy: 0.6500 - val_loss: 0.8234
# Epoch 20/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6522 - loss: 0.8155 - val_accuracy: 0.6500 - val_loss: 0.8121
# Epoch 21/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6522 - loss: 0.8047 - val_accuracy: 0.6500 - val_loss: 0.8010
# Epoch 22/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6522 - loss: 0.7940 - val_accuracy: 0.6500 - val_loss: 0.7901
# Epoch 23/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6522 - loss: 0.7836 - val_accuracy: 0.6500 - val_loss: 0.7795
# Epoch 24/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6522 - loss: 0.7733 - val_accuracy: 0.6500 - val_loss: 0.7690
# Epoch 25/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6522 - loss: 0.7632 - val_accuracy: 0.6500 - val_loss: 0.7587
# Epoch 26/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6522 - loss: 0.7532 - val_accuracy: 0.6500 - val_loss: 0.7487
# Epoch 27/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6522 - loss: 0.7434 - val_accuracy: 0.6500 - val_loss: 0.7388
# Epoch 28/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6522 - loss: 0.7338 - val_accuracy: 0.6500 - val_loss: 0.7291
# Epoch 29/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6522 - loss: 0.7244 - val_accuracy: 0.6500 - val_loss: 0.7197
# Epoch 30/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6522 - loss: 0.7152 - val_accuracy: 0.6500 - val_loss: 0.7105
# Epoch 31/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6522 - loss: 0.7062 - val_accuracy: 0.6500 - val_loss: 0.7016
# Epoch 32/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6522 - loss: 0.6974 - val_accuracy: 0.6500 - val_loss: 0.6929
# Epoch 33/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6522 - loss: 0.6888 - val_accuracy: 0.6500 - val_loss: 0.6843
# Epoch 34/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6522 - loss: 0.6804 - val_accuracy: 0.6500 - val_loss: 0.6761
# Epoch 35/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6522 - loss: 0.6721 - val_accuracy: 0.6500 - val_loss: 0.6680
# Epoch 36/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6522 - loss: 0.6641 - val_accuracy: 0.6500 - val_loss: 0.6602
# Epoch 37/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6522 - loss: 0.6563 - val_accuracy: 0.6500 - val_loss: 0.6526
# Epoch 38/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6522 - loss: 0.6486 - val_accuracy: 0.6500 - val_loss: 0.6451
# Epoch 39/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6522 - loss: 0.6411 - val_accuracy: 0.6500 - val_loss: 0.6379
# Epoch 40/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6522 - loss: 0.6338 - val_accuracy: 0.6500 - val_loss: 0.6309
# Epoch 41/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6522 - loss: 0.6267 - val_accuracy: 0.6500 - val_loss: 0.6241
# Epoch 42/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6522 - loss: 0.6198 - val_accuracy: 0.6500 - val_loss: 0.6175
# Epoch 43/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6522 - loss: 0.6131 - val_accuracy: 0.6500 - val_loss: 0.6110
# Epoch 44/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6522 - loss: 0.6065 - val_accuracy: 0.6500 - val_loss: 0.6048
# Epoch 45/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6522 - loss: 0.6002 - val_accuracy: 0.6500 - val_loss: 0.5987
# Epoch 46/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6522 - loss: 0.5940 - val_accuracy: 0.6500 - val_loss: 0.5928
# Epoch 47/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6522 - loss: 0.5880 - val_accuracy: 0.6500 - val_loss: 0.5871
# Epoch 48/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6658 - loss: 0.5821 - val_accuracy: 0.6500 - val_loss: 0.5815
# Epoch 49/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6755 - loss: 0.5764 - val_accuracy: 0.6500 - val_loss: 0.5761
# Epoch 50/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6755 - loss: 0.5708 - val_accuracy: 0.6500 - val_loss: 0.5709
# Epoch 51/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6755 - loss: 0.5654 - val_accuracy: 0.6500 - val_loss: 0.5658
# Epoch 52/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6755 - loss: 0.5601 - val_accuracy: 0.6500 - val_loss: 0.5608
# Epoch 53/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6755 - loss: 0.5549 - val_accuracy: 0.7000 - val_loss: 0.5560
# Epoch 54/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6755 - loss: 0.5499 - val_accuracy: 0.7000 - val_loss: 0.5513
# Epoch 55/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6755 - loss: 0.5450 - val_accuracy: 0.7000 - val_loss: 0.5468
# Epoch 56/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7105 - loss: 0.5401 - val_accuracy: 0.7000 - val_loss: 0.5423
# Epoch 57/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7105 - loss: 0.5354 - val_accuracy: 0.7000 - val_loss: 0.5380
# Epoch 58/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7105 - loss: 0.5308 - val_accuracy: 0.7500 - val_loss: 0.5338
# Epoch 59/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7141 - loss: 0.5263 - val_accuracy: 0.7500 - val_loss: 0.5297
# Epoch 60/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7141 - loss: 0.5219 - val_accuracy: 0.7500 - val_loss: 0.5257
# Epoch 61/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7141 - loss: 0.5176 - val_accuracy: 0.7500 - val_loss: 0.5219
# Epoch 62/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7192 - loss: 0.5135 - val_accuracy: 0.7500 - val_loss: 0.5181
# Epoch 63/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7192 - loss: 0.5094 - val_accuracy: 0.7500 - val_loss: 0.5144
# Epoch 64/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7192 - loss: 0.5054 - val_accuracy: 0.7500 - val_loss: 0.5108
# Epoch 65/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7192 - loss: 0.5015 - val_accuracy: 0.7500 - val_loss: 0.5073
# Epoch 66/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7192 - loss: 0.4976 - val_accuracy: 0.7500 - val_loss: 0.5038
# Epoch 67/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7192 - loss: 0.4939 - val_accuracy: 0.7500 - val_loss: 0.5005
# Epoch 68/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7325 - loss: 0.4901 - val_accuracy: 0.7500 - val_loss: 0.4972
# Epoch 69/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7461 - loss: 0.4865 - val_accuracy: 0.7500 - val_loss: 0.4940
# Epoch 70/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7738 - loss: 0.4829 - val_accuracy: 0.7500 - val_loss: 0.4908
# Epoch 71/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7738 - loss: 0.4794 - val_accuracy: 0.7500 - val_loss: 0.4877
# Epoch 72/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7953 - loss: 0.4759 - val_accuracy: 0.7500 - val_loss: 0.4847
# Epoch 73/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8004 - loss: 0.4725 - val_accuracy: 0.7500 - val_loss: 0.4818
# Epoch 74/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8004 - loss: 0.4692 - val_accuracy: 0.7500 - val_loss: 0.4789
# Epoch 75/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8004 - loss: 0.4659 - val_accuracy: 0.7500 - val_loss: 0.4761
# Epoch 76/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8126 - loss: 0.4626 - val_accuracy: 0.7500 - val_loss: 0.4733
# Epoch 77/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8262 - loss: 0.4594 - val_accuracy: 0.7500 - val_loss: 0.4705
# Epoch 78/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8457 - loss: 0.4563 - val_accuracy: 0.7500 - val_loss: 0.4678
# Epoch 79/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8707 - loss: 0.4532 - val_accuracy: 0.7500 - val_loss: 0.4652
# Epoch 80/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8804 - loss: 0.4501 - val_accuracy: 0.7500 - val_loss: 0.4626
# Epoch 81/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8940 - loss: 0.4471 - val_accuracy: 0.7500 - val_loss: 0.4600
# Epoch 82/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9368 - loss: 0.4441 - val_accuracy: 0.7500 - val_loss: 0.4575
# Epoch 83/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9368 - loss: 0.4412 - val_accuracy: 0.8000 - val_loss: 0.4550
# Epoch 84/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9368 - loss: 0.4383 - val_accuracy: 0.8000 - val_loss: 0.4525
# Epoch 85/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9419 - loss: 0.4354 - val_accuracy: 0.8000 - val_loss: 0.4501
# Epoch 86/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9471 - loss: 0.4325 - val_accuracy: 0.8000 - val_loss: 0.4477
# Epoch 87/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9471 - loss: 0.4297 - val_accuracy: 0.8000 - val_loss: 0.4453
# Epoch 88/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9471 - loss: 0.4269 - val_accuracy: 0.8000 - val_loss: 0.4430
# Epoch 89/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9471 - loss: 0.4242 - val_accuracy: 0.8000 - val_loss: 0.4407
# Epoch 90/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9471 - loss: 0.4214 - val_accuracy: 0.8500 - val_loss: 0.4385
# Epoch 91/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9471 - loss: 0.4187 - val_accuracy: 0.8500 - val_loss: 0.4362
# Epoch 92/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9471 - loss: 0.4161 - val_accuracy: 0.8500 - val_loss: 0.4340
# Epoch 93/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9607 - loss: 0.4134 - val_accuracy: 0.8500 - val_loss: 0.4318
# Epoch 94/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9607 - loss: 0.4108 - val_accuracy: 0.8500 - val_loss: 0.4296
# Epoch 95/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9607 - loss: 0.4082 - val_accuracy: 0.8500 - val_loss: 0.4275
# Epoch 96/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9607 - loss: 0.4057 - val_accuracy: 0.8500 - val_loss: 0.4253
# Epoch 97/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.4031 - val_accuracy: 0.8500 - val_loss: 0.4232
# Epoch 98/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.4006 - val_accuracy: 0.8500 - val_loss: 0.4212
# Epoch 99/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.3981 - val_accuracy: 0.8500 - val_loss: 0.4191
# Epoch 100/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9658 - loss: 0.3956 - val_accuracy: 0.8500 - val_loss: 0.4170
# Epoch 101/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.3932 - val_accuracy: 0.9000 - val_loss: 0.4150
# Epoch 102/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9658 - loss: 0.3907 - val_accuracy: 0.9000 - val_loss: 0.4130
# Epoch 103/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.3883 - val_accuracy: 0.9000 - val_loss: 0.4110
# Epoch 104/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.3859 - val_accuracy: 0.9000 - val_loss: 0.4091
# Epoch 105/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.3835 - val_accuracy: 0.9000 - val_loss: 0.4071
# Epoch 106/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.3811 - val_accuracy: 0.9000 - val_loss: 0.4052
# Epoch 107/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9658 - loss: 0.3788 - val_accuracy: 0.9500 - val_loss: 0.4033
# Epoch 108/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.3765 - val_accuracy: 0.9500 - val_loss: 0.4014
# Epoch 109/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.3742 - val_accuracy: 0.9500 - val_loss: 0.3996
# Epoch 110/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9658 - loss: 0.3718 - val_accuracy: 0.9500 - val_loss: 0.3977
# Epoch 111/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.3696 - val_accuracy: 0.9500 - val_loss: 0.3959
# Epoch 112/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.3673 - val_accuracy: 0.9500 - val_loss: 0.3940
# Epoch 113/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.3651 - val_accuracy: 0.9500 - val_loss: 0.3922
# Epoch 114/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9658 - loss: 0.3628 - val_accuracy: 0.9500 - val_loss: 0.3903
# Epoch 115/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.3606 - val_accuracy: 0.9500 - val_loss: 0.3885
# Epoch 116/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9658 - loss: 0.3584 - val_accuracy: 0.9500 - val_loss: 0.3867
# Epoch 117/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9658 - loss: 0.3562 - val_accuracy: 0.9500 - val_loss: 0.3849
# Epoch 118/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.3541 - val_accuracy: 0.9500 - val_loss: 0.3831
# Epoch 119/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9658 - loss: 0.3519 - val_accuracy: 0.9500 - val_loss: 0.3813
# Epoch 120/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9658 - loss: 0.3498 - val_accuracy: 0.9500 - val_loss: 0.3796
# Epoch 121/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9658 - loss: 0.3476 - val_accuracy: 0.9500 - val_loss: 0.3778
# Epoch 122/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9658 - loss: 0.3455 - val_accuracy: 0.9500 - val_loss: 0.3760
# Epoch 123/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9658 - loss: 0.3434 - val_accuracy: 0.9500 - val_loss: 0.3743
# Epoch 124/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.3413 - val_accuracy: 0.9500 - val_loss: 0.3725
# Epoch 125/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9709 - loss: 0.3392 - val_accuracy: 0.9500 - val_loss: 0.3708
# Epoch 126/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9709 - loss: 0.3371 - val_accuracy: 0.9500 - val_loss: 0.3691
# Epoch 127/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9709 - loss: 0.3350 - val_accuracy: 0.9500 - val_loss: 0.3674
# Epoch 128/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9709 - loss: 0.3330 - val_accuracy: 0.9500 - val_loss: 0.3657
# Epoch 129/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9806 - loss: 0.3309 - val_accuracy: 0.9500 - val_loss: 0.3640
# Epoch 130/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9806 - loss: 0.3289 - val_accuracy: 0.9500 - val_loss: 0.3623
# Epoch 131/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9806 - loss: 0.3268 - val_accuracy: 0.9500 - val_loss: 0.3606
# Epoch 132/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9806 - loss: 0.3248 - val_accuracy: 0.9500 - val_loss: 0.3589
# Epoch 133/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9806 - loss: 0.3228 - val_accuracy: 0.9500 - val_loss: 0.3573
# Epoch 134/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9806 - loss: 0.3208 - val_accuracy: 0.9500 - val_loss: 0.3556
# Epoch 135/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9806 - loss: 0.3187 - val_accuracy: 0.9500 - val_loss: 0.3540
# Epoch 136/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9806 - loss: 0.3167 - val_accuracy: 0.9500 - val_loss: 0.3523
# Epoch 137/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9903 - loss: 0.3147 - val_accuracy: 0.9500 - val_loss: 0.3507
# Epoch 138/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9903 - loss: 0.3127 - val_accuracy: 0.9500 - val_loss: 0.3490
# Epoch 139/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9903 - loss: 0.3106 - val_accuracy: 0.9500 - val_loss: 0.3473
# Epoch 140/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9903 - loss: 0.3086 - val_accuracy: 0.9500 - val_loss: 0.3456
# Epoch 141/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9903 - loss: 0.3066 - val_accuracy: 0.9500 - val_loss: 0.3440
# Epoch 142/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9903 - loss: 0.3046 - val_accuracy: 0.9500 - val_loss: 0.3423
# Epoch 143/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9903 - loss: 0.3025 - val_accuracy: 0.9500 - val_loss: 0.3407
# Epoch 144/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9903 - loss: 0.3005 - val_accuracy: 0.9500 - val_loss: 0.3390
# Epoch 145/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9903 - loss: 0.2985 - val_accuracy: 0.9500 - val_loss: 0.3374
# Epoch 146/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9903 - loss: 0.2965 - val_accuracy: 0.9500 - val_loss: 0.3358
# Epoch 147/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9903 - loss: 0.2944 - val_accuracy: 0.9500 - val_loss: 0.3341
# Epoch 148/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9903 - loss: 0.2924 - val_accuracy: 0.9500 - val_loss: 0.3325
# Epoch 149/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9903 - loss: 0.2904 - val_accuracy: 0.9500 - val_loss: 0.3309
# Epoch 150/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9903 - loss: 0.2884 - val_accuracy: 0.9500 - val_loss: 0.3292
# Epoch 151/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9903 - loss: 0.2864 - val_accuracy: 0.9500 - val_loss: 0.3276
# Epoch 152/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9903 - loss: 0.2845 - val_accuracy: 0.9500 - val_loss: 0.3260
# Epoch 153/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9903 - loss: 0.2825 - val_accuracy: 0.9500 - val_loss: 0.3243
# Epoch 154/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9955 - loss: 0.2806 - val_accuracy: 0.9500 - val_loss: 0.3226
# Epoch 155/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9955 - loss: 0.2787 - val_accuracy: 0.9500 - val_loss: 0.3209
# Epoch 156/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9955 - loss: 0.2767 - val_accuracy: 0.9500 - val_loss: 0.3192
# Epoch 157/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9955 - loss: 0.2748 - val_accuracy: 0.9500 - val_loss: 0.3175
# Epoch 158/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9955 - loss: 0.2729 - val_accuracy: 0.9500 - val_loss: 0.3159
# Epoch 159/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9955 - loss: 0.2710 - val_accuracy: 0.9500 - val_loss: 0.3142
# Epoch 160/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9955 - loss: 0.2691 - val_accuracy: 0.9500 - val_loss: 0.3126
# Epoch 161/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9955 - loss: 0.2673 - val_accuracy: 0.9500 - val_loss: 0.3110
# Epoch 162/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.2654 - val_accuracy: 0.9500 - val_loss: 0.3093
# Epoch 163/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.2636 - val_accuracy: 0.9500 - val_loss: 0.3077
# Epoch 164/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9955 - loss: 0.2618 - val_accuracy: 0.9500 - val_loss: 0.3062
# Epoch 165/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.2600 - val_accuracy: 0.9500 - val_loss: 0.3046
# Epoch 166/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.2582 - val_accuracy: 0.9500 - val_loss: 0.3030
# Epoch 167/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.2564 - val_accuracy: 0.9500 - val_loss: 0.3015
# Epoch 168/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9955 - loss: 0.2546 - val_accuracy: 0.9500 - val_loss: 0.2999
# Epoch 169/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.2528 - val_accuracy: 0.9500 - val_loss: 0.2984
# Epoch 170/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9955 - loss: 0.2511 - val_accuracy: 0.9500 - val_loss: 0.2969
# Epoch 171/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9955 - loss: 0.2493 - val_accuracy: 0.9500 - val_loss: 0.2954
# Epoch 172/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.2476 - val_accuracy: 0.9500 - val_loss: 0.2939
# Epoch 173/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.2459 - val_accuracy: 0.9500 - val_loss: 0.2924
# Epoch 174/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.2442 - val_accuracy: 0.9500 - val_loss: 0.2909
# Epoch 175/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9955 - loss: 0.2425 - val_accuracy: 0.9500 - val_loss: 0.2894
# Epoch 176/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9955 - loss: 0.2409 - val_accuracy: 0.9500 - val_loss: 0.2880
# Epoch 177/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9955 - loss: 0.2392 - val_accuracy: 0.9500 - val_loss: 0.2865
# Epoch 178/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.2376 - val_accuracy: 0.9500 - val_loss: 0.2851
# Epoch 179/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.2360 - val_accuracy: 0.9500 - val_loss: 0.2837
# Epoch 180/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.2344 - val_accuracy: 0.9500 - val_loss: 0.2823
# Epoch 181/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9955 - loss: 0.2328 - val_accuracy: 0.9500 - val_loss: 0.2809
# Epoch 182/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.2312 - val_accuracy: 0.9500 - val_loss: 0.2795
# Epoch 183/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.2296 - val_accuracy: 0.9500 - val_loss: 0.2781
# Epoch 184/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.2280 - val_accuracy: 0.9500 - val_loss: 0.2767
# Epoch 185/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.2265 - val_accuracy: 0.9500 - val_loss: 0.2754
# Epoch 186/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9955 - loss: 0.2250 - val_accuracy: 0.9500 - val_loss: 0.2740
# Epoch 187/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9955 - loss: 0.2234 - val_accuracy: 0.9500 - val_loss: 0.2727
# Epoch 188/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9955 - loss: 0.2219 - val_accuracy: 0.9500 - val_loss: 0.2714
# Epoch 189/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9955 - loss: 0.2205 - val_accuracy: 0.9500 - val_loss: 0.2700
# Epoch 190/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9955 - loss: 0.2190 - val_accuracy: 0.9500 - val_loss: 0.2687
# Epoch 191/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.2175 - val_accuracy: 0.9500 - val_loss: 0.2674
# Epoch 192/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - loss: 0.2161 - val_accuracy: 0.9500 - val_loss: 0.2661
# Epoch 193/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9955 - loss: 0.2146 - val_accuracy: 0.9500 - val_loss: 0.2648
# Epoch 194/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.2132 - val_accuracy: 0.9500 - val_loss: 0.2636
# Epoch 195/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.2118 - val_accuracy: 0.9500 - val_loss: 0.2623
# Epoch 196/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9955 - loss: 0.2104 - val_accuracy: 0.9500 - val_loss: 0.2610
# Epoch 197/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.2090 - val_accuracy: 0.9500 - val_loss: 0.2598
# Epoch 198/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.2076 - val_accuracy: 0.9500 - val_loss: 0.2585
# Epoch 199/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.2063 - val_accuracy: 0.9500 - val_loss: 0.2573
# Epoch 200/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9858 - loss: 0.2049 - val_accuracy: 0.9500 - val_loss: 0.2561
# Epoch 201/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.2036 - val_accuracy: 0.9500 - val_loss: 0.2549
# Epoch 202/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.2023 - val_accuracy: 0.9500 - val_loss: 0.2537
# Epoch 203/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.2010 - val_accuracy: 0.9500 - val_loss: 0.2525
# Epoch 204/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.1997 - val_accuracy: 0.9500 - val_loss: 0.2513
# Epoch 205/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.1984 - val_accuracy: 0.9500 - val_loss: 0.2501
# Epoch 206/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.1971 - val_accuracy: 0.9500 - val_loss: 0.2490
# Epoch 207/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1959 - val_accuracy: 0.9500 - val_loss: 0.2478
# Epoch 208/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1946 - val_accuracy: 0.9500 - val_loss: 0.2466
# Epoch 209/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9858 - loss: 0.1934 - val_accuracy: 0.9500 - val_loss: 0.2455
# Epoch 210/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1922 - val_accuracy: 0.9500 - val_loss: 0.2444
# Epoch 211/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1910 - val_accuracy: 0.9500 - val_loss: 0.2433
# Epoch 212/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1897 - val_accuracy: 0.9500 - val_loss: 0.2422
# Epoch 213/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1886 - val_accuracy: 0.9500 - val_loss: 0.2411
# Epoch 214/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.1874 - val_accuracy: 0.9500 - val_loss: 0.2400
# Epoch 215/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1862 - val_accuracy: 0.9500 - val_loss: 0.2389
# Epoch 216/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1851 - val_accuracy: 0.9500 - val_loss: 0.2378
# Epoch 217/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1840 - val_accuracy: 0.9500 - val_loss: 0.2367
# Epoch 218/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1828 - val_accuracy: 0.9500 - val_loss: 0.2357
# Epoch 219/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1817 - val_accuracy: 0.9500 - val_loss: 0.2346
# Epoch 220/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1806 - val_accuracy: 0.9500 - val_loss: 0.2336
# Epoch 221/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1795 - val_accuracy: 0.9500 - val_loss: 0.2326
# Epoch 222/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1784 - val_accuracy: 0.9500 - val_loss: 0.2315
# Epoch 223/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1774 - val_accuracy: 0.9500 - val_loss: 0.2305
# Epoch 224/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1763 - val_accuracy: 0.9500 - val_loss: 0.2295
# Epoch 225/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1752 - val_accuracy: 0.9500 - val_loss: 0.2285
# Epoch 226/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1742 - val_accuracy: 0.9500 - val_loss: 0.2275
# Epoch 227/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1732 - val_accuracy: 0.9500 - val_loss: 0.2266
# Epoch 228/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1721 - val_accuracy: 0.9500 - val_loss: 0.2256
# Epoch 229/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1711 - val_accuracy: 0.9500 - val_loss: 0.2246
# Epoch 230/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1701 - val_accuracy: 0.9500 - val_loss: 0.2237
# Epoch 231/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1691 - val_accuracy: 0.9500 - val_loss: 0.2227
# Epoch 232/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1681 - val_accuracy: 0.9500 - val_loss: 0.2218
# Epoch 233/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1672 - val_accuracy: 0.9500 - val_loss: 0.2209
# Epoch 234/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1662 - val_accuracy: 0.9500 - val_loss: 0.2199
# Epoch 235/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1653 - val_accuracy: 0.9500 - val_loss: 0.2190
# Epoch 236/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1643 - val_accuracy: 0.9500 - val_loss: 0.2181
# Epoch 237/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1634 - val_accuracy: 0.9500 - val_loss: 0.2172
# Epoch 238/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1624 - val_accuracy: 0.9500 - val_loss: 0.2163
# Epoch 239/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1615 - val_accuracy: 0.9500 - val_loss: 0.2154
# Epoch 240/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1606 - val_accuracy: 0.9500 - val_loss: 0.2145
# Epoch 241/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1597 - val_accuracy: 0.9500 - val_loss: 0.2137
# Epoch 242/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1588 - val_accuracy: 0.9500 - val_loss: 0.2128
# Epoch 243/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1579 - val_accuracy: 0.9500 - val_loss: 0.2119
# Epoch 244/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1570 - val_accuracy: 0.9500 - val_loss: 0.2111
# Epoch 245/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1562 - val_accuracy: 0.9500 - val_loss: 0.2103
# Epoch 246/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1553 - val_accuracy: 0.9500 - val_loss: 0.2094
# Epoch 247/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.1545 - val_accuracy: 0.9500 - val_loss: 0.2086
# Epoch 248/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1536 - val_accuracy: 0.9500 - val_loss: 0.2078
# Epoch 249/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1528 - val_accuracy: 0.9500 - val_loss: 0.2070
# Epoch 250/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1520 - val_accuracy: 0.9500 - val_loss: 0.2061
# Epoch 251/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1511 - val_accuracy: 0.9500 - val_loss: 0.2053
# Epoch 252/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1503 - val_accuracy: 0.9500 - val_loss: 0.2045
# Epoch 253/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1495 - val_accuracy: 0.9500 - val_loss: 0.2037
# Epoch 254/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1487 - val_accuracy: 0.9500 - val_loss: 0.2030
# Epoch 255/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.1479 - val_accuracy: 0.9500 - val_loss: 0.2022
# Epoch 256/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1471 - val_accuracy: 0.9500 - val_loss: 0.2014
# Epoch 257/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.1464 - val_accuracy: 0.9500 - val_loss: 0.2007
# Epoch 258/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1456 - val_accuracy: 0.9500 - val_loss: 0.1999
# Epoch 259/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1448 - val_accuracy: 0.9500 - val_loss: 0.1991
# Epoch 260/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.1441 - val_accuracy: 0.9500 - val_loss: 0.1984
# Epoch 261/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1433 - val_accuracy: 0.9500 - val_loss: 0.1977
# Epoch 262/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1426 - val_accuracy: 0.9500 - val_loss: 0.1969
# Epoch 263/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1419 - val_accuracy: 0.9500 - val_loss: 0.1962
# Epoch 264/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1411 - val_accuracy: 0.9500 - val_loss: 0.1955
# Epoch 265/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.1404 - val_accuracy: 0.9500 - val_loss: 0.1948
# Epoch 266/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.1397 - val_accuracy: 0.9500 - val_loss: 0.1940
# Epoch 267/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1390 - val_accuracy: 0.9500 - val_loss: 0.1933
# Epoch 268/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.1383 - val_accuracy: 0.9500 - val_loss: 0.1926
# Epoch 269/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1376 - val_accuracy: 0.9500 - val_loss: 0.1919
# Epoch 270/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1369 - val_accuracy: 0.9500 - val_loss: 0.1913
# Epoch 271/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1362 - val_accuracy: 0.9500 - val_loss: 0.1906
# Epoch 272/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.1355 - val_accuracy: 0.9500 - val_loss: 0.1899
# Epoch 273/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9858 - loss: 0.1349 - val_accuracy: 0.9500 - val_loss: 0.1892
# Epoch 274/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1342 - val_accuracy: 0.9500 - val_loss: 0.1885
# Epoch 275/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.1335 - val_accuracy: 0.9500 - val_loss: 0.1879
# Epoch 276/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1329 - val_accuracy: 0.9500 - val_loss: 0.1872
# Epoch 277/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.1322 - val_accuracy: 0.9500 - val_loss: 0.1866
# Epoch 278/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1316 - val_accuracy: 0.9500 - val_loss: 0.1859
# Epoch 279/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1310 - val_accuracy: 0.9500 - val_loss: 0.1853
# Epoch 280/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9858 - loss: 0.1303 - val_accuracy: 0.9500 - val_loss: 0.1846
# Epoch 281/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1297 - val_accuracy: 0.9500 - val_loss: 0.1840
# Epoch 282/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1291 - val_accuracy: 0.9500 - val_loss: 0.1834
# Epoch 283/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1285 - val_accuracy: 0.9500 - val_loss: 0.1827
# Epoch 284/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.1279 - val_accuracy: 0.9500 - val_loss: 0.1821
# Epoch 285/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1273 - val_accuracy: 0.9500 - val_loss: 0.1815
# Epoch 286/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1267 - val_accuracy: 0.9500 - val_loss: 0.1809
# Epoch 287/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.1261 - val_accuracy: 0.9500 - val_loss: 0.1803
# Epoch 288/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9858 - loss: 0.1255 - val_accuracy: 0.9500 - val_loss: 0.1797
# Epoch 289/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1249 - val_accuracy: 0.9500 - val_loss: 0.1791
# Epoch 290/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1243 - val_accuracy: 0.9500 - val_loss: 0.1785
# Epoch 291/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1238 - val_accuracy: 0.9500 - val_loss: 0.1779
# Epoch 292/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1232 - val_accuracy: 0.9500 - val_loss: 0.1773
# Epoch 293/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.1227 - val_accuracy: 0.9500 - val_loss: 0.1768
# Epoch 294/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1221 - val_accuracy: 0.9500 - val_loss: 0.1762
# Epoch 295/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1215 - val_accuracy: 0.9500 - val_loss: 0.1756
# Epoch 296/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1210 - val_accuracy: 0.9500 - val_loss: 0.1750
# Epoch 297/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.1205 - val_accuracy: 0.9500 - val_loss: 0.1745
# Epoch 298/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.1199 - val_accuracy: 0.9500 - val_loss: 0.1739
# Epoch 299/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1194 - val_accuracy: 0.9500 - val_loss: 0.1734
# Epoch 300/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.1189 - val_accuracy: 0.9500 - val_loss: 0.1728
# Epoch 301/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1184 - val_accuracy: 0.9500 - val_loss: 0.1723
# Epoch 302/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.1178 - val_accuracy: 0.9500 - val_loss: 0.1717
# Epoch 303/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.1173 - val_accuracy: 0.9500 - val_loss: 0.1712
# Epoch 304/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1168 - val_accuracy: 0.9500 - val_loss: 0.1707
# Epoch 305/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1163 - val_accuracy: 0.9500 - val_loss: 0.1701
# Epoch 306/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1158 - val_accuracy: 0.9500 - val_loss: 0.1696
# Epoch 307/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1153 - val_accuracy: 0.9500 - val_loss: 0.1691
# Epoch 308/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1148 - val_accuracy: 0.9500 - val_loss: 0.1686
# Epoch 309/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1143 - val_accuracy: 0.9500 - val_loss: 0.1681
# Epoch 310/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.1139 - val_accuracy: 0.9500 - val_loss: 0.1675
# Epoch 311/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1134 - val_accuracy: 0.9500 - val_loss: 0.1670
# Epoch 312/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.1129 - val_accuracy: 0.9500 - val_loss: 0.1665
# Epoch 313/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1124 - val_accuracy: 0.9500 - val_loss: 0.1660
# Epoch 314/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1120 - val_accuracy: 0.9500 - val_loss: 0.1655
# Epoch 315/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1115 - val_accuracy: 0.9500 - val_loss: 0.1651
# Epoch 316/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.1110 - val_accuracy: 0.9500 - val_loss: 0.1646
# Epoch 317/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1106 - val_accuracy: 0.9500 - val_loss: 0.1641
# Epoch 318/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1101 - val_accuracy: 0.9500 - val_loss: 0.1636
# Epoch 319/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1097 - val_accuracy: 0.9500 - val_loss: 0.1631
# Epoch 320/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.1092 - val_accuracy: 0.9500 - val_loss: 0.1626
# Epoch 321/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1088 - val_accuracy: 0.9500 - val_loss: 0.1622
# Epoch 322/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1084 - val_accuracy: 0.9500 - val_loss: 0.1617
# Epoch 323/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1079 - val_accuracy: 0.9500 - val_loss: 0.1612
# Epoch 324/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1075 - val_accuracy: 0.9500 - val_loss: 0.1608
# Epoch 325/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.1071 - val_accuracy: 0.9500 - val_loss: 0.1603
# Epoch 326/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1067 - val_accuracy: 0.9500 - val_loss: 0.1599
# Epoch 327/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1062 - val_accuracy: 0.9500 - val_loss: 0.1594
# Epoch 328/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.1058 - val_accuracy: 0.9500 - val_loss: 0.1589
# Epoch 329/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.1054 - val_accuracy: 0.9500 - val_loss: 0.1585
# Epoch 330/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1050 - val_accuracy: 0.9500 - val_loss: 0.1581
# Epoch 331/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1046 - val_accuracy: 0.9500 - val_loss: 0.1576
# Epoch 332/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1042 - val_accuracy: 0.9500 - val_loss: 0.1572
# Epoch 333/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1038 - val_accuracy: 0.9500 - val_loss: 0.1567
# Epoch 334/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1034 - val_accuracy: 0.9500 - val_loss: 0.1563
# Epoch 335/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1030 - val_accuracy: 0.9500 - val_loss: 0.1559
# Epoch 336/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1026 - val_accuracy: 0.9500 - val_loss: 0.1555
# Epoch 337/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1022 - val_accuracy: 0.9500 - val_loss: 0.1550
# Epoch 338/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1018 - val_accuracy: 0.9500 - val_loss: 0.1546
# Epoch 339/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1015 - val_accuracy: 0.9500 - val_loss: 0.1542
# Epoch 340/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1011 - val_accuracy: 0.9500 - val_loss: 0.1538
# Epoch 341/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.1007 - val_accuracy: 0.9500 - val_loss: 0.1534
# Epoch 342/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.1003 - val_accuracy: 0.9500 - val_loss: 0.1529
# Epoch 343/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1000 - val_accuracy: 0.9500 - val_loss: 0.1525
# Epoch 344/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0996 - val_accuracy: 0.9500 - val_loss: 0.1521
# Epoch 345/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0992 - val_accuracy: 0.9500 - val_loss: 0.1517
# Epoch 346/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0989 - val_accuracy: 0.9500 - val_loss: 0.1513
# Epoch 347/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0985 - val_accuracy: 0.9500 - val_loss: 0.1509
# Epoch 348/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0982 - val_accuracy: 0.9500 - val_loss: 0.1505
# Epoch 349/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0978 - val_accuracy: 0.9500 - val_loss: 0.1501
# Epoch 350/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0975 - val_accuracy: 0.9500 - val_loss: 0.1498
# Epoch 351/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0971 - val_accuracy: 0.9500 - val_loss: 0.1494
# Epoch 352/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0968 - val_accuracy: 0.9500 - val_loss: 0.1490
# Epoch 353/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0965 - val_accuracy: 0.9500 - val_loss: 0.1486
# Epoch 354/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0961 - val_accuracy: 0.9500 - val_loss: 0.1482
# Epoch 355/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0958 - val_accuracy: 0.9500 - val_loss: 0.1478
# Epoch 356/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0955 - val_accuracy: 0.9500 - val_loss: 0.1475
# Epoch 357/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0951 - val_accuracy: 0.9500 - val_loss: 0.1471
# Epoch 358/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0948 - val_accuracy: 0.9500 - val_loss: 0.1467
# Epoch 359/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0945 - val_accuracy: 0.9500 - val_loss: 0.1464
# Epoch 360/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0942 - val_accuracy: 0.9500 - val_loss: 0.1460
# Epoch 361/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0938 - val_accuracy: 0.9500 - val_loss: 0.1456
# Epoch 362/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0935 - val_accuracy: 0.9500 - val_loss: 0.1453
# Epoch 363/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0932 - val_accuracy: 0.9500 - val_loss: 0.1449
# Epoch 364/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0929 - val_accuracy: 0.9500 - val_loss: 0.1445
# Epoch 365/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0926 - val_accuracy: 0.9500 - val_loss: 0.1442
# Epoch 366/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0923 - val_accuracy: 0.9500 - val_loss: 0.1438
# Epoch 367/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0920 - val_accuracy: 0.9500 - val_loss: 0.1435
# Epoch 368/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0917 - val_accuracy: 0.9500 - val_loss: 0.1431
# Epoch 369/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0914 - val_accuracy: 0.9500 - val_loss: 0.1428
# Epoch 370/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.0911 - val_accuracy: 0.9500 - val_loss: 0.1424
# Epoch 371/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0908 - val_accuracy: 0.9500 - val_loss: 0.1421
# Epoch 372/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0905 - val_accuracy: 0.9500 - val_loss: 0.1418
# Epoch 373/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.0902 - val_accuracy: 0.9500 - val_loss: 0.1414
# Epoch 374/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0899 - val_accuracy: 0.9500 - val_loss: 0.1411
# Epoch 375/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0896 - val_accuracy: 0.9500 - val_loss: 0.1407
# Epoch 376/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0893 - val_accuracy: 0.9500 - val_loss: 0.1404
# Epoch 377/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0890 - val_accuracy: 0.9500 - val_loss: 0.1401
# Epoch 378/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0888 - val_accuracy: 0.9500 - val_loss: 0.1397
# Epoch 379/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.0885 - val_accuracy: 0.9500 - val_loss: 0.1394
# Epoch 380/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0882 - val_accuracy: 0.9500 - val_loss: 0.1391
# Epoch 381/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0879 - val_accuracy: 0.9500 - val_loss: 0.1388
# Epoch 382/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0877 - val_accuracy: 0.9500 - val_loss: 0.1384
# Epoch 383/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.0874 - val_accuracy: 0.9500 - val_loss: 0.1381
# Epoch 384/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0871 - val_accuracy: 0.9500 - val_loss: 0.1378
# Epoch 385/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0869 - val_accuracy: 0.9500 - val_loss: 0.1375
# Epoch 386/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.0866 - val_accuracy: 0.9500 - val_loss: 0.1372
# Epoch 387/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.0863 - val_accuracy: 0.9500 - val_loss: 0.1369
# Epoch 388/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0861 - val_accuracy: 0.9500 - val_loss: 0.1366
# Epoch 389/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0858 - val_accuracy: 0.9500 - val_loss: 0.1362
# Epoch 390/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0855 - val_accuracy: 0.9500 - val_loss: 0.1359
# Epoch 391/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9858 - loss: 0.0853 - val_accuracy: 0.9500 - val_loss: 0.1356
# Epoch 392/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0850 - val_accuracy: 0.9500 - val_loss: 0.1353
# Epoch 393/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.0848 - val_accuracy: 0.9500 - val_loss: 0.1350
# Epoch 394/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0845 - val_accuracy: 0.9500 - val_loss: 0.1347
# Epoch 395/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0843 - val_accuracy: 0.9500 - val_loss: 0.1344
# Epoch 396/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0840 - val_accuracy: 0.9500 - val_loss: 0.1341
# Epoch 397/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0838 - val_accuracy: 0.9500 - val_loss: 0.1338
# Epoch 398/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0835 - val_accuracy: 0.9500 - val_loss: 0.1335
# Epoch 399/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0833 - val_accuracy: 0.9500 - val_loss: 0.1332
# Epoch 400/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0831 - val_accuracy: 0.9500 - val_loss: 0.1329
# Epoch 401/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0828 - val_accuracy: 0.9500 - val_loss: 0.1327
# Epoch 402/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0826 - val_accuracy: 0.9500 - val_loss: 0.1324
# Epoch 403/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0824 - val_accuracy: 0.9500 - val_loss: 0.1321
# Epoch 404/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0821 - val_accuracy: 0.9500 - val_loss: 0.1318
# Epoch 405/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0819 - val_accuracy: 0.9500 - val_loss: 0.1315
# Epoch 406/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9858 - loss: 0.0817 - val_accuracy: 0.9500 - val_loss: 0.1312
# Epoch 407/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0814 - val_accuracy: 0.9500 - val_loss: 0.1310
# Epoch 408/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0812 - val_accuracy: 0.9500 - val_loss: 0.1307
# Epoch 409/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0810 - val_accuracy: 0.9500 - val_loss: 0.1304
# Epoch 410/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0808 - val_accuracy: 0.9500 - val_loss: 0.1301
# Epoch 411/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0805 - val_accuracy: 0.9500 - val_loss: 0.1298
# Epoch 412/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0803 - val_accuracy: 0.9500 - val_loss: 0.1296
# Epoch 413/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0801 - val_accuracy: 0.9500 - val_loss: 0.1293
# Epoch 414/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0799 - val_accuracy: 0.9500 - val_loss: 0.1290
# Epoch 415/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0797 - val_accuracy: 0.9500 - val_loss: 0.1288
# Epoch 416/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0795 - val_accuracy: 0.9500 - val_loss: 0.1285
# Epoch 417/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0792 - val_accuracy: 0.9500 - val_loss: 0.1282
# Epoch 418/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0790 - val_accuracy: 0.9500 - val_loss: 0.1280
# Epoch 419/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0788 - val_accuracy: 0.9500 - val_loss: 0.1277
# Epoch 420/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0786 - val_accuracy: 0.9500 - val_loss: 0.1274
# Epoch 421/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0784 - val_accuracy: 0.9500 - val_loss: 0.1272
# Epoch 422/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0782 - val_accuracy: 0.9500 - val_loss: 0.1269
# Epoch 423/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9858 - loss: 0.0780 - val_accuracy: 0.9500 - val_loss: 0.1267
# Epoch 424/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.0778 - val_accuracy: 0.9500 - val_loss: 0.1264
# Epoch 425/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0776 - val_accuracy: 0.9500 - val_loss: 0.1261
# Epoch 426/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0774 - val_accuracy: 0.9500 - val_loss: 0.1259
# Epoch 427/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0772 - val_accuracy: 0.9500 - val_loss: 0.1256
# Epoch 428/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0770 - val_accuracy: 0.9500 - val_loss: 0.1254
# Epoch 429/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0768 - val_accuracy: 0.9500 - val_loss: 0.1251
# Epoch 430/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0766 - val_accuracy: 0.9500 - val_loss: 0.1249
# Epoch 431/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0764 - val_accuracy: 0.9500 - val_loss: 0.1246
# Epoch 432/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0762 - val_accuracy: 0.9500 - val_loss: 0.1244
# Epoch 433/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0760 - val_accuracy: 0.9500 - val_loss: 0.1241
# Epoch 434/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0758 - val_accuracy: 0.9500 - val_loss: 0.1239
# Epoch 435/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0756 - val_accuracy: 0.9500 - val_loss: 0.1237
# Epoch 436/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0754 - val_accuracy: 0.9500 - val_loss: 0.1234
# Epoch 437/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0753 - val_accuracy: 0.9500 - val_loss: 0.1232
# Epoch 438/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0751 - val_accuracy: 0.9500 - val_loss: 0.1229
# Epoch 439/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0749 - val_accuracy: 0.9500 - val_loss: 0.1227
# Epoch 440/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0747 - val_accuracy: 0.9500 - val_loss: 0.1225
# Epoch 441/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0745 - val_accuracy: 0.9500 - val_loss: 0.1222
# Epoch 442/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0743 - val_accuracy: 0.9500 - val_loss: 0.1220
# Epoch 443/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0742 - val_accuracy: 0.9500 - val_loss: 0.1218
# Epoch 444/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0740 - val_accuracy: 0.9500 - val_loss: 0.1215
# Epoch 445/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0738 - val_accuracy: 0.9500 - val_loss: 0.1213
# Epoch 446/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0736 - val_accuracy: 0.9500 - val_loss: 0.1211
# Epoch 447/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0735 - val_accuracy: 0.9500 - val_loss: 0.1208
# Epoch 448/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0733 - val_accuracy: 0.9500 - val_loss: 0.1206
# Epoch 449/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0731 - val_accuracy: 0.9500 - val_loss: 0.1204
# Epoch 450/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0729 - val_accuracy: 0.9500 - val_loss: 0.1201
# Epoch 451/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0728 - val_accuracy: 0.9500 - val_loss: 0.1199
# Epoch 452/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0726 - val_accuracy: 0.9500 - val_loss: 0.1197
# Epoch 453/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0724 - val_accuracy: 0.9500 - val_loss: 0.1195
# Epoch 454/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0723 - val_accuracy: 0.9500 - val_loss: 0.1193
# Epoch 455/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0721 - val_accuracy: 0.9500 - val_loss: 0.1190
# Epoch 456/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0719 - val_accuracy: 0.9500 - val_loss: 0.1188
# Epoch 457/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0718 - val_accuracy: 0.9500 - val_loss: 0.1186
# Epoch 458/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0716 - val_accuracy: 0.9500 - val_loss: 0.1184
# Epoch 459/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0714 - val_accuracy: 0.9500 - val_loss: 0.1182
# Epoch 460/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0713 - val_accuracy: 0.9500 - val_loss: 0.1179
# Epoch 461/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0711 - val_accuracy: 0.9500 - val_loss: 0.1177
# Epoch 462/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0710 - val_accuracy: 0.9500 - val_loss: 0.1175
# Epoch 463/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0708 - val_accuracy: 0.9500 - val_loss: 0.1173
# Epoch 464/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.0707 - val_accuracy: 0.9500 - val_loss: 0.1171
# Epoch 465/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0705 - val_accuracy: 0.9500 - val_loss: 0.1169
# Epoch 466/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.0703 - val_accuracy: 0.9500 - val_loss: 0.1167
# Epoch 467/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0702 - val_accuracy: 0.9500 - val_loss: 0.1165
# Epoch 468/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0700 - val_accuracy: 0.9500 - val_loss: 0.1162
# Epoch 469/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0699 - val_accuracy: 0.9500 - val_loss: 0.1160
# Epoch 470/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0697 - val_accuracy: 0.9500 - val_loss: 0.1158
# Epoch 471/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.0696 - val_accuracy: 0.9500 - val_loss: 0.1156
# Epoch 472/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0694 - val_accuracy: 0.9500 - val_loss: 0.1154
# Epoch 473/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0693 - val_accuracy: 0.9500 - val_loss: 0.1152
# Epoch 474/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0691 - val_accuracy: 0.9500 - val_loss: 0.1150
# Epoch 475/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0690 - val_accuracy: 0.9500 - val_loss: 0.1148
# Epoch 476/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0688 - val_accuracy: 0.9500 - val_loss: 0.1146
# Epoch 477/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0687 - val_accuracy: 0.9500 - val_loss: 0.1144
# Epoch 478/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0686 - val_accuracy: 0.9500 - val_loss: 0.1142
# Epoch 479/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9858 - loss: 0.0684 - val_accuracy: 0.9500 - val_loss: 0.1140
# Epoch 480/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0683 - val_accuracy: 0.9500 - val_loss: 0.1138
# Epoch 481/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0681 - val_accuracy: 0.9500 - val_loss: 0.1136
# Epoch 482/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0680 - val_accuracy: 0.9500 - val_loss: 0.1134
# Epoch 483/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - loss: 0.0678 - val_accuracy: 0.9500 - val_loss: 0.1132
# Epoch 484/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0677 - val_accuracy: 0.9500 - val_loss: 0.1130
# Epoch 485/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0676 - val_accuracy: 0.9500 - val_loss: 0.1128
# Epoch 486/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9858 - loss: 0.0674 - val_accuracy: 0.9500 - val_loss: 0.1127
# Epoch 487/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.0673 - val_accuracy: 0.9500 - val_loss: 0.1125
# Epoch 488/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9858 - loss: 0.0672 - val_accuracy: 0.9500 - val_loss: 0.1123
# Epoch 489/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.0670 - val_accuracy: 0.9500 - val_loss: 0.1121
# Epoch 490/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0669 - val_accuracy: 0.9500 - val_loss: 0.1119
# Epoch 491/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0668 - val_accuracy: 0.9500 - val_loss: 0.1117
# Epoch 492/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9858 - loss: 0.0666 - val_accuracy: 0.9500 - val_loss: 0.1115
# Epoch 493/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9858 - loss: 0.0665 - val_accuracy: 0.9500 - val_loss: 0.1113
# Epoch 494/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9858 - loss: 0.0664 - val_accuracy: 0.9500 - val_loss: 0.1111
# Epoch 495/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9858 - loss: 0.0662 - val_accuracy: 0.9500 - val_loss: 0.1110
# Epoch 496/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9858 - loss: 0.0661 - val_accuracy: 0.9500 - val_loss: 0.1108
# Epoch 497/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0660 - val_accuracy: 0.9500 - val_loss: 0.1106
# Epoch 498/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9858 - loss: 0.0658 - val_accuracy: 0.9500 - val_loss: 0.1104
# Epoch 499/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0657 - val_accuracy: 0.9500 - val_loss: 0.1102
# Epoch 500/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0656 - val_accuracy: 0.9500 - val_loss: 0.1100

# %%
# Create a figure with two vertically stacked subplots
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(15, 6), sharex=True)

# Plot training and validation loss
ax1.plot(history['loss'], label='Training loss', alpha=.8)
ax1.plot(history['val_loss'], label='Validation loss', alpha=.8)
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=.3)

# Plot training and validation accuracy
ax2.plot(history['accuracy'], label='Training accuracy', alpha=.8)
ax2.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
ax2.set_title('Accuracy')
ax2.legend()
ax2.grid(alpha=.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %% [markdown]
# ### 🕹️ Use the Model - Make Inference

# %% [markdown]
# **Binary Classification Metrics**
#
# <img src="https://drive.google.com/uc?export=view&id=1dUVBtRp6yJmfr1-cwUmWtKX2UfgozNaj" width="250"/>
#
# $\text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}$
#
# $\text{Precision} = \frac{TP}{TP + FP}$
#
# $\text{Recall} = \frac{TP}{TP + FN}$
#
# $F1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}$
#
# &nbsp;
#
# ---
#
# **Multiclass Classification Metrics**
#
# <img src="https://drive.google.com/uc?export=view&id=1yDfrbcjHPTqFx9P5ZPhi07S5XVcXjd6g" width="300"/>
#
# $\text{Accuracy} = \sum_{i=1}^{N} \frac{TP_i}{TP_i + TN_i + FP_i + FN_i}$
#
# $\text{Precision}_i = \frac{TP_i}{TP_i + FP_i}$
#
# $\text{Recall}_i = \frac{TP_i}{TP_i + FN_i}$
#
# $F1_i = 2 \cdot \frac{\text{Precision}_i \cdot \text{Recall}_i}{\text{Precision}_i + \text{Recall}_i}$
#
# &nbsp;
#
# **Macro Averaging**
#
# $\text{Precision}_{macro} = \frac{1}{N} \sum_{i=1}^{N} \text{Precision}_i$
#
# $\text{Recall}_{macro} = \frac{1}{N} \sum_{i=1}^{N} \text{Recall}_i$
#
# $F1_{macro} = \frac{1}{N} \sum_{i=1}^{N} F1_i$
#
# &nbsp;
#
# **Weighted Macro Averaging**
#
# $\text{Precision}_{weighted} = \sum_{i=1}^{N} \left( \frac{N_i}{N} \times \text{Precision}_i \right)$
#
# $\text{Recall}_{weighted} = \sum_{i=1}^{N} \left( \frac{N_i}{N} \times \text{Recall}_i \right)$
#
# $F1_{weighted} = \sum_{i=1}^{N} \left( \frac{N_i}{N} \times F1_i \right)$

# %%
# Load the saved model
model = tfk.models.load_model('Iris_Feedforward_95.0.keras')

# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "FeedforwardNeuralNetwork"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 4)                    │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Hidden (Dense)                      │ (None, 16)                   │            80 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ HiddenActivation (Activation)       │ (None, 16)                   │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Output (Dense)                      │ (None, 3)                    │            51 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Softmax (Activation)                │ (None, 3)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 395 (1.55 KB)
#  Trainable params: 131 (524.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 264 (1.04 KB)

# %%
# Predict class probabilities and get predicted classes
train_predictions = model.predict(X_train, verbose=0)
train_predictions = np.argmax(train_predictions, axis=-1)

# Extract ground truth classes
train_gt = np.argmax(y_train, axis=-1)

# Calculate and display training set accuracy
train_accuracy = accuracy_score(train_gt, train_predictions)
print(f'Accuracy score over the train set: {round(train_accuracy, 4)}')

# Calculate and display training set precision
train_precision = precision_score(train_gt, train_predictions, average='weighted')
print(f'Precision score over the train set: {round(train_precision, 4)}')

# Calculate and display training set recall
train_recall = recall_score(train_gt, train_predictions, average='weighted')
print(f'Recall score over the train set: {round(train_recall, 4)}')

# Calculate and display training set F1 score
train_f1 = f1_score(train_gt, train_predictions, average='weighted')
print(f'F1 score over the train set: {round(train_f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(train_gt, train_predictions)

# Create labels combining confusion matrix values
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix with class labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=labels, fmt='', xticklabels=['Setosa', 'Versicolor', 'Virginica'], yticklabels=['Setosa', 'Versicolor', 'Virginica'], cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the train set: 0.9727
# Precision score over the train set: 0.9729
# Recall score over the train set: 0.9727
# F1 score over the train set: 0.9727

# %%
# Predict class probabilities and get predicted classes
val_predictions = model.predict(X_val, verbose=0)
val_predictions = np.argmax(val_predictions, axis=-1)

# Extract ground truth classes
val_gt = np.argmax(y_val, axis=-1)

# Calculate and display validation set accuracy
val_accuracy = accuracy_score(val_gt, val_predictions)
print(f'Accuracy score over the validation set: {round(val_accuracy, 4)}')

# Calculate and display validation set precision
val_precision = precision_score(val_gt, val_predictions, average='weighted')
print(f'Precision score over the validation set: {round(val_precision, 4)}')

# Calculate and display validation set recall
val_recall = recall_score(val_gt, val_predictions, average='weighted')
print(f'Recall score over the validation set: {round(val_recall, 4)}')

# Calculate and display validation set F1 score
val_f1 = f1_score(val_gt, val_predictions, average='weighted')
print(f'F1 score over the validation set: {round(val_f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(val_gt, val_predictions)

# Create labels combining confusion matrix values
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix with class labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=labels, fmt='', xticklabels=['Setosa', 'Versicolor', 'Virginica'], yticklabels=['Setosa', 'Versicolor', 'Virginica'], cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the validation set: 0.95
# Precision score over the validation set: 0.9571
# Recall score over the validation set: 0.95
# F1 score over the validation set: 0.95

# %%
# Predict class probabilities and get predicted classes
test_predictions = model.predict(X_test, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)

# Extract ground truth classes
test_gt = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
test_accuracy = accuracy_score(test_gt, test_predictions)
print(f'Accuracy score over the test set: {round(test_accuracy, 4)}')

# Calculate and display test set precision
test_precision = precision_score(test_gt, test_predictions, average='weighted')
print(f'Precision score over the test set: {round(test_precision, 4)}')

# Calculate and display test set recall
test_recall = recall_score(test_gt, test_predictions, average='weighted')
print(f'Recall score over the test set: {round(test_recall, 4)}')

# Calculate and display test set F1 score
test_f1 = f1_score(test_gt, test_predictions, average='weighted')
print(f'F1 score over the test set: {round(test_f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(test_gt, test_predictions)

# Create labels combining confusion matrix values
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix with class labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=labels, fmt='', xticklabels=['Setosa', 'Versicolor', 'Virginica'], yticklabels=['Setosa', 'Versicolor', 'Virginica'], cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 0.95
# Precision score over the test set: 0.9562
# Recall score over the test set: 0.95
# F1 score over the test set: 0.9497

# %% [markdown]
# ### Pinguins dataset
#
# Perform the same classification analysis on the Penguins dataset to predict the correct species
#
# <img src="https://allisonhorst.github.io/palmerpenguins/reference/figures/lter_penguins.png" width="800">
#
# ```
# ...
#
# # Load Data
# os.environ["DATASET_NAME"] = "penguins.csv"
# os.environ["DATASET_URL"] = "1qn1P6_KW08wGRfSkTlzBoDCyVb18T3Lk"
# if not os.path.exists(os.environ["DATASET_NAME"]):
#     print("Downloading data...")
#     ! gdown -q ${DATASET_URL}
#     print("Download completed")
# else:
#     print("Data already downloaded. Using cached data...")
# dataset = pd.read_csv('penguins.csv')
#
# # Inspect Data
# ...
#
# # Process Data
# ...
#
#
# # Build the Model
# ...
#
# # Train the Model
# ...
#
# # Use the Model - Make Inferece
# ...
#
# ```
